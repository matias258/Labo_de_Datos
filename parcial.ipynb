# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so
# Out:
# /home/matias/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
penguins = sns.load_dataset("penguins")
penguins.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0  Adelie  Torgersen            39.1           18.7              181.0  \
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female

# %%
penguins_adelie = penguins[penguins["species"] == "Adelie"]
penguins_adelie["body_mass_g"].mean()
# Out:
# 3700.662251655629

# %%
penguins_adelie_dream = penguins_adelie[penguins_adelie["island"] == "Dream"]
penguins_adelie_dream["body_mass_g"].mean()
# Out:
# 3688.3928571428573

# %%
penguins_adelie["body_mass_g"].std()
# Out:
# 458.5661259101348

# %%
penguins["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguins[penguins["species"] == "Chinstrap"]["body_mass_g"].std()
# Out:
# 384.3350813871914

# %%
penguins[penguins["species"] == "Gentoo"]["body_mass_g"].std()
# Out:
# 504.11623665709163

# %%
penguins["body_mass_g"].std()
# Out:
# 801.9545356980956

# %%
from gapminder import gapminder

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
paises = ["Argentina", "Brazil", "Chile", "Uruguay"]
df = gapminder[(gapminder["country"] == "Argentina") | (gapminder["country"] == "Brazil") | (gapminder["country"] == "Chile") | (gapminder["country"] == "Uruguay")]
df["country"].unique()
# Out:
# array(['Argentina', 'Brazil', 'Chile', 'Uruguay'], dtype=object)

# %%
(
    so.Plot(df, x = "year", y = "gdpPercap", color = "country")
    .add(so.Line())
)

# %%
df = gapminder.query('country in @paises')
df.head()
# Out:
#       country continent  year  lifeExp       pop    gdpPercap
# 48  Argentina  Americas  1952   62.485  17876956  5911.315053
# 49  Argentina  Americas  1957   64.399  19610538  6856.856212
# 50  Argentina  Americas  1962   65.142  21283783  7133.166023
# 51  Argentina  Americas  1967   65.634  22934225  8052.953021
# 52  Argentina  Americas  1972   67.065  24779799  9443.038526
