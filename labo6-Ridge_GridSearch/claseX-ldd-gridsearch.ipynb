# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/Estudiante/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: pandas>=1.2 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (22.0)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install formulaic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: formulaic in /home/Estudiante/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from formulaic) (4.4.0)
# Requirement already satisfied: wrapt>=1.0 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from formulaic) (1.14.1)
# Requirement already satisfied: scipy>=1.6 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from formulaic) (1.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /home/Estudiante/.local/lib/python3.10/site-packages (from formulaic) (1.3.0)
# Requirement already satisfied: numpy>=1.16.5 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from formulaic) (1.23.1)
# Requirement already satisfied: pandas>=1.0 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from formulaic) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from pandas>=1.0->formulaic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from pandas>=1.0->formulaic) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/alc/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.0->formulaic) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

from scipy import stats
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from formulaic import model_matrix

# %%
def generar_datos(n=1000, amin=0, amax=20, bmin=5, bmax=20, seed=2024):
    np.random.seed(seed)
    brange = bmax - bmin
    a = stats.uniform.rvs(size=n, loc=amin, scale=amax - amin)
    b = stats.norm.rvs(size=n, loc=bmin + brange / 2, scale=brange / 8)
    eps = stats.norm.rvs(size=n, loc=0, scale=4)
    y = 1 + 3 * a - 2 * b + 1.5 * a * b - 0.8 * a**2 + 0.6 * b**2 + eps
    return pd.DataFrame({"a": a, "b": b}), pd.Series(y)


X, y = generar_datos()

# %%
sns.pairplot(X)

# %%
fig, axs= plt.subplots(1, 2, figsize = (10, 5))
for i, col in enumerate(X):
    sns.scatterplot(x=X[col], y=y, ax=axs[i])
    axs[i].set_title(f"y vs {col}")

# %%
test_split = 0.5
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_split)

# %%
lr1 = LinearRegression()
lr1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr1.intercept_
beta1 = pd.Series(lr1.coef_, index=X_train.columns)
beta1["intercept"] = lr1.intercept_
beta1
# Out:
# a              5.625882
# b             28.054812
# intercept   -222.000189
# dtype: float64

# %%
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))

# %%
y_pred = lr1.predict(X_test)
print(
    "# RMSE",
    f"Train: {rmse(lr1.predict(X_train), y_train):.4f}",
    "Test:  %.4f" % rmse(y_pred, y_test),
    sep="\n",
)
# Out:
# # RMSE
# Train: 26.4619
# Test:  28.3876

# %%
df_test = pd.concat(
    [
        X_test,
        y_test.rename("y"),
        pd.Series(y_pred, name="y_pred", index=y_test.index),
    ],
    axis=1,
)
df_test.head()
# Out:
#              a          b           y      y_pred
# 945  11.788097  15.111320  294.504866  268.263479
# 794  12.712614  11.884333  197.336893  182.932185
# 946   0.165232  11.440478   61.383078   99.889832
# 993  14.631676  13.923646  279.389867  250.941150
# 159   9.197219  13.880550  238.595650  219.158502

# %%
#Otra forma de hacerlo

df_test = X_test.copy()
df_test["y"] = y_test
df_test["y_pred"] = y_pred
df_test["resid"] = df_test["y"] - df_test["y_pred"]
df_test.head()
# Out:
#              a          b           y      y_pred      resid
# 945  11.788097  15.111320  294.504866  268.263479  26.241387
# 794  12.712614  11.884333  197.336893  182.932185  14.404708
# 946   0.165232  11.440478   61.383078   99.889832 -38.506754
# 993  14.631676  13.923646  279.389867  250.941150  28.448717
# 159   9.197219  13.880550  238.595650  219.158502  19.437148

# %% [markdown]
# ### Análisis de residuos

# %%
fig, axs= plt.subplots(1, 3, figsize = (15, 5))
for versus, ax in zip(["y", "a", "b"], axs.flatten()):
    sns.scatterplot(x=versus, y="resid", data=df_test, ax=ax)
    ax.set_title(f"Residuos vs {versus}")

# %% [markdown]
# Pareciera haber alguna relación cuadrática entre los residuos y $a$, entonces...

# %%
formula = "~ poly(a, 2, raw=True) * b"
# Como solo tiene RHS, no devuelve $y$
X_train2 = model_matrix(formula, data=X_train)
X_train2.head()
# pueden explicar por qué quedan las columnas que quedas?
# Out:
#      Intercept  poly(a, 2, raw=True)[0]  poly(a, 2, raw=True)[1]          b  \
# 816        1.0                 0.886459                 0.785810  13.425392
# 465        1.0                11.300314               127.697090  14.502627
# 109        1.0                 2.798665                 7.832525  10.982316
# 295        1.0                17.280935               298.630710  11.063778
# 998        1.0                13.226307               174.935187  14.507008
#
#      poly(a, 2, raw=True)[0]:b  poly(a, 2, raw=True)[1]:b
# 816                  11.901065                  10.549810
# 465                 163.884238                1851.943304
# 109                  30.735822                  86.019265
# 295                 191.192432                3303.983962
# 998                 191.874130                2537.786080

# %%
import re


def nombres_poli(s):
    repl = lambda m: f"{m.group(1)}^{int(m.group(2))+1}"
    nombres = re.sub(r"poly\((\w), \d+, raw=True\)\[(\d)\]", repl, s).replace("^1", "") # Regex
    return nombres

np.vectorize(nombres_poli)(X_train2.columns)
# Out:
# array(['Intercept', 'a', 'a^2', 'b', 'a:b', 'a^2:b'], dtype='<U9')

# %% [markdown]
# ### np.vectorize

# %%
assert all(
    np.vectorize(nombres_poli)(X_train2.columns)
    == [nombres_poli(c) for c in X_train2.columns]
)

# %%
lr2 = LinearRegression(fit_intercept=False)  # Ya está incluido en model_matrix
lr2.fit(X_train2, y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
def betas(lr, train):
    beta = pd.Series(lr.coef_, index=train.columns)
    if lr.fit_intercept:
        beta["Intercept"] = lr.intercept_
    beta.index = beta.index.map(nombres_poli)
    return beta


betas(lr2, X_train2)
# Out:
# Intercept   -81.003109
# a             1.158016
# a^2          -0.708357
# b            12.191623
# a:b           1.648849
# a^2:b        -0.007244
# dtype: float64

# %%
def mostrar_rmse(lr, X_train, y_train, X_test, y_test):
    print(
        "# RMSE",
        f"Train: {rmse(lr.predict(X_train), y_train):.4f}",
        "Test:  %.4f" % rmse(lr.predict(X_test), y_test),
        sep="\n",
    )


mostrar_rmse(lr2, X_train2, y_train, model_matrix(formula, data=X_test), y_test)
# Out:
# # RMSE
# Train: 4.8640
# Test:  5.4504

# %%
y_pred2 = lr2.predict(model_matrix(formula, data=X_test))
df_test = df_test.rename(columns={"y_pred": "y_pred1", "resid": "resid1"})
df_test["y_pred2"] = y_pred2
df_test["resid2"] = df_test["y"] - df_test["y_pred2"]

# %%
sns.scatterplot(x="resid2", y="resid1", data=df_test.abs(), label="Modelo 2")
plt.axline((0, 0), slope=1, color="gray", linestyle="dotted")
plt.suptitle(f"Residuos de ambos modelos")
perc_mejora = 100 * (df_test.resid2.abs() < df_test.resid1.abs()).mean()
plt.title(f"{perc_mejora:.2f}% de las observaciones 'ajustan mejor' con lr2", fontsize=10)
# Out:
# Text(0.5, 1.0, "92.40% de las observaciones 'ajustan mejor' con lr2")

# %%
# Otra manera de calcular RMSE Test
df_test[["resid1", "resid2"]].pow(2).mean().apply(np.sqrt)
# Out:
# resid1    28.387585
# resid2     5.450421
# dtype: float64

# %% [markdown]
# Revisamos otra vez la estructura de los residuos

# %%
fig, axs= plt.subplots(1, 3, figsize = (15, 5))
for versus, ax in zip(["y", "a", "b"], axs.flatten()):
    sns.scatterplot(x=versus, y="resid2", data=df_test, ax=ax)
    ax.set_title(f"Residuos vs {versus}")

# %% [markdown]
# $y \sim a$ parece bien capturado, pero aún queda una estructura contra $b$. Será cuadrática también?

# %%
formula = "~ 0 + poly(a, 2, raw=True) * poly(b, 2, raw=True)"
X_train3 = model_matrix(formula, data=X_train)
X_train3.shape, np.vectorize(nombres_poli)(X_train3.columns)
# Out:
# ((500, 8),
#  array(['a', 'a^2', 'b', 'b^2', 'a:b', 'a^2:b', 'a:b^2', 'a^2:b^2'],
#        dtype='<U7'))

# %% [markdown]
# ¿Por qué hay 8 terminos y no $3 \times 3=9$? ¿Se acabará algún día este proceso?
#
# 0 + : nos saca el intersect

# %% [markdown]
# ## Regrsión Grieta (AKA Ridge)
#
# Una hipótesis: si le doy suficientes grados de libertad al modelo, y regularizo fuertemente, debería encontrar un modelo simple que ajuste a los datos sin demasiado esfuerzo. Será verdad?

# %%
from sklearn.linear_model import Ridge
formula = "~ 0 + poly(a, 3, raw=True) * poly(b, 3, raw=True)"
X_train4 = model_matrix(formula, data=X_train)

lr4 = Ridge(alpha=100)
lr4.fit(X_train4, y_train)
# Out:
# Ridge(alpha=100)

# %%
lr4.coef_
# Out:
# array([ 2.29253648e-02, -3.31803537e-02, -3.98273491e-02,  8.05865229e-03,
#         2.20980321e-02,  2.64523772e-02,  1.40918425e-01,  2.79047556e-02,
#         3.44998446e-03,  2.92298529e-01, -2.18984194e-02,  3.16772887e-04,
#        -1.28721366e-02,  1.14870019e-03, -2.60161346e-05])

# %%
mostrar_rmse(lr4, X_train4, y_train, model_matrix(formula, data=X_test), y_test)
# Out:
# # RMSE
# Train: 4.1769
# Test:  4.1800

# %%
pd.DataFrame({"lr2": betas(lr2, X_train2), "lr4": betas(lr4, X_train4)}).round(4)
# Out:
#                lr2      lr4
# Intercept -81.0031  13.2460
# a           1.1580   0.0229
# a:b         1.6488   0.1409
# a:b^2          NaN   0.2923
# a:b^3          NaN  -0.0129
# a^2        -0.7084  -0.0332
# a^2:b      -0.0072   0.0279
# a^2:b^2        NaN  -0.0219
# a^2:b^3        NaN   0.0011
# a^3            NaN  -0.0398
# a^3:b          NaN   0.0034
# a^3:b^2        NaN   0.0003
# a^3:b^3        NaN  -0.0000
# b          12.1916   0.0081
# b^2            NaN   0.0221
# b^3            NaN   0.0265

# %% [markdown]
# Nada mal! Pero se podrá mejorar aún más? Cómo encunetro el valor óptimo de la penalización $\alpha$? CV al rescate

# %% [markdown]
# ## Validación cruzada con scikit-learn
# ### np.logspace

# %%
np.logspace(0, 2, 5)
# Out:
# array([  1.        ,   3.16227766,  10.        ,  31.6227766 ,
#        100.        ])

# %%
alfas = np.logspace(-3, 3, 61)

# %%
alfas[:5].round(3), alfas[-5:].round(3)
# Out:
# (array([0.001, 0.001, 0.002, 0.002, 0.003]),
#  array([ 398.107,  501.187,  630.957,  794.328, 1000.   ]))

# %%
def norma(vec):
    return np.sqrt((vec ** 2).sum())

# %%
assert norma(np.array([3, 4])) == 5

# %%
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


rmse_train = {}
rmse_test = {}
beta_norm = {}
intercept = {}
for alfa in alfas:
    ridge = Ridge(alpha=alfa)
    ridge.fit(X_train4, y_train)
    rmse_train[alfa] = rmse(ridge.predict(X_train4), y_train)
    rmse_test[alfa] = rmse(ridge.predict(model_matrix(formula, X_test)), y_test)
    beta_norm[alfa] = norma(ridge.coef_)
    intercept[alfa] = ridge.intercept_

    logger.info(f"Alfa: {alfa.round(3):.3f}")
# Out:
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.14303e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.001
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.24839e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.001
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.38114e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.002
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.54844e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.002
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.75934e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.003
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.02527e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.003
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.3607e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.004
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.78398e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.005
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.31834e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.006
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.99328e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.008
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.84623e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.010
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.9247e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.013
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.28904e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.016
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.01578e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.020
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.12019e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.025
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.39702e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.032
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.74759e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.040
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.19148e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.050
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.75336e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.063
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.46438e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.079
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.36374e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.100
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.50099e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.126
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.9387e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.158
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.75617e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.200
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.10533e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.251
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.39584e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.316
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.76182e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.398
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.22315e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.501
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.22698e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.631
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.04042e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 0.794
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.06589e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 1.000
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.35934e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 1.259
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.99167e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 1.585
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.00528e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# INFO:__main__:Alfa: 1.995
# INFO:__main__:Alfa: 2.512
# INFO:__main__:Alfa: 3.162
# INFO:__main__:Alfa: 3.981
# INFO:__main__:Alfa: 5.012
# INFO:__main__:Alfa: 6.310
# INFO:__main__:Alfa: 7.943
# INFO:__main__:Alfa: 10.000
# INFO:__main__:Alfa: 12.589
# INFO:__main__:Alfa: 15.849
# INFO:__main__:Alfa: 19.953
# INFO:__main__:Alfa: 25.119
# INFO:__main__:Alfa: 31.623
# INFO:__main__:Alfa: 39.811
# INFO:__main__:Alfa: 50.119
# INFO:__main__:Alfa: 63.096
# INFO:__main__:Alfa: 79.433
# INFO:__main__:Alfa: 100.000
# INFO:__main__:Alfa: 125.893
# INFO:__main__:Alfa: 158.489
# INFO:__main__:Alfa: 199.526
# INFO:__main__:Alfa: 251.189
# INFO:__main__:Alfa: 316.228
# INFO:__main__:Alfa: 398.107
# INFO:__main__:Alfa: 501.187
# INFO:__main__:Alfa: 630.957
# INFO:__main__:Alfa: 794.328
# INFO:__main__:Alfa: 1000.000

# %% [markdown]
# Fíjense qué interesante: efecivamente para alfas muy pequeños, cuando Ridge es casi igual a la reg. lineal "vainilla", la matrix efectivamente está mal condicionada.

# %%
data = pd.DataFrame(
    {
        "rmse_train": rmse_train,
        "rmse_test": rmse_test,
        "beta_norm": beta_norm,
        "intercept": intercept,
    }
).reset_index(names="alfa")

# %%
data
# Out:
#            alfa  rmse_train  rmse_test  beta_norm  intercept
# 0      0.001000    4.173566   4.146711  38.132789 -72.520042
# 1      0.001259    4.173628   4.144228  34.940078 -66.464811
# 2      0.001585    4.173704   4.141723  31.611669 -60.143607
# 3      0.001995    4.173790   4.139269  28.231059 -53.711348
# 4      0.002512    4.173885   4.136934  24.887270 -47.332970
# ..          ...         ...        ...        ...        ...
# 56   398.107171    4.177326   4.177849   0.316762  13.975092
# 57   501.187234    4.177405   4.176075   0.315599  14.067639
# 58   630.957344    4.177505   4.173771   0.314426  14.167422
# 59   794.328235    4.177641   4.170867   0.313146  14.281581
# 60  1000.000000    4.177838   4.167295   0.311675  14.418193
#
# [61 rows x 5 columns]

# %% [markdown]
# ### Interludio: $\alpha \rightarrow \infty$?

# %%
ridge = Ridge(alpha=1e100)
ridge.fit(X_train4, y_train)
ridge.intercept_
# Out:
# 185.712557987755

# %% [markdown]
# ### np.isclose

# %%
assert np.isclose(y_train.mean(), ridge.intercept_)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharex=True)
sns.lineplot(data=data, x="alfa", y="beta_norm", label="norma beta", ax=axs[0])
# sns.lineplot(data=data, x="alfa", y="intercept", label="intercept", ax=axs[0])
# sns.lineplot(data=data, x="alfa", y="intercept", label="intercept")
sns.lineplot(data=data, x="alfa", y="rmse_train", label="RMSE Train", ax=axs[1])
sns.lineplot(data=data, x="alfa", y="rmse_test", label="RMSE Test", ax=axs[1])
plt.xscale("log")  # Probar comentando esta línea
plt.legend()

# %%
optimo = data.iloc[data.rmse_test.idxmin()]
optimo
# Out:
# alfa          0.039811
# rmse_train    4.174773
# rmse_test     4.125246
# beta_norm     2.998271
# intercept    -2.903671
# Name: 16, dtype: float64

# %%
lr4 = Ridge(alpha=optimo.alfa)
lr4.fit(X_train4, y_train)
mostrar_rmse(lr4, X_train4, y_train, model_matrix(formula, X_test), y_test)
# Out:
# # RMSE
# Train: 4.1748
# Test:  4.1252
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.74759e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %%
betas(lr4, X_train4).abs().sort_values(ascending=False)
# Out:
# Intercept    2.903671
# b            2.283448
# a            1.862634
# a:b          0.485267
# a:b^2        0.203970
# a^2          0.158632
# a^3          0.035109
# b^2          0.030877
# a^2:b        0.028748
# b^3          0.024556
# a^2:b^2      0.010699
# a:b^3        0.009026
# a^3:b        0.004958
# a^2:b^3      0.000688
# a^3:b^3      0.000012
# a^3:b^2      0.000007
# dtype: float64

# %% [markdown]
# Para reflexionar: ¿Qué es más importante, $$0.000012\ a^3:b^3$$ o $$0.485267\ a:b$$? ¿De qué depende?

# %% [markdown]
# ### Una vez más, con ~~sentimiento~~ `GridSearchCV`

# %%
from sklearn.model_selection import GridSearchCV

# param_grid = {"alpha": alfas}
mas_alfas = np.unique(np.concatenate([alfas, np.logspace(-4, 4, 41)]))
param_grid = {"alpha": mas_alfas}
gs = GridSearchCV(
    Ridge(),
    param_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    return_train_score=True,
)
gs.fit(X_train4, y_train)

gs.best_params_
# Out:
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.67713e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.94808e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.89361e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.64877e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.56307e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.98851e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.23232e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.18169e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.93435e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.88072e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.48215e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.68295e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.63841e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.38711e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.38431e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.26487e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.39754e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.36259e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.10506e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.18282e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.05062e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.0531e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.05111e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.24384e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.04493e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.24758e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.23297e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.23335e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.1051e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.24586e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.38592e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.35933e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.36135e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.23205e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.387e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.56025e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.5186e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.52266e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.39205e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.56486e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.78e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.71939e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.72599e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.59378e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.78905e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.05706e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.97262e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.98237e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.84818e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.07171e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.05706e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.97262e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.98237e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.84818e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.07171e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.4065e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.29211e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.30574e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.16912e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.4282e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.84741e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.69536e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.71378e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.57419e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.87797e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.40396e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.20458e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.22887e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.08568e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.44562e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.10684e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.84796e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.87945e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.73189e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.16237e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.99498e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.66133e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.70158e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.54873e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.06774e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.11782e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.69017e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.7411e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.58183e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.21182e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.53814e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.99226e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.0562e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.88911e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.65804e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.33565e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.64094e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.72078e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.54403e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.48668e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.16114e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.07292e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.08286e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.06397e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.17992e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.44934e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.33746e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.34983e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.32939e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.47238e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.44934e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.33746e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.34983e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.32939e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.47238e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.81437e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.67259e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.68802e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.66554e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.8422e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.27669e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.09706e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.11637e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.09121e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.30976e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.86213e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.63451e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.65881e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.63005e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.90073e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.6033e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.31473e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.34547e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.31193e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.64746e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.6033e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.31473e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.34547e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.31193e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.64746e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.54133e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.17523e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.21432e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.17448e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.59078e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.72825e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.26336e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.31324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.26527e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.78227e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.22993e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.63893e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.70272e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.64446e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.28715e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.12993e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.37744e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.45924e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.38798e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.18813e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.15339e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.05746e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.06793e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.05927e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.15899e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.45776e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.33527e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.34859e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.33777e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.46258e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.84134e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.68409e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.70296e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.68779e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.84619e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.69864e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.12487e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.14849e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.45211e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.32882e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.37205e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.68267e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.71217e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.06742e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.36863e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.22051e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.86622e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.91671e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.84332e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.22502e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.29012e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.84651e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.90749e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.82235e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.30479e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.63926e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.08269e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.15703e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.05847e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.66682e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.34194e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.64229e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.73377e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.62026e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.38575e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.04921e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.61098e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.72454e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.59493e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /opt/miniconda3/envs/alc/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.05563e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# {'alpha': 1584.893192461114}

# %% [markdown]
# Obtengo el mejor modelo que minimice el score:
# - alpha = 1584.893

# %%
cv_results_ = pd.DataFrame(gs.cv_results_)[
    ["param_alpha", "mean_test_score", "mean_train_score"]
]
cv_results_[["mean_test_score", "mean_train_score"]] *= -1

# %%
cv_results_.head()
# Out:
#   param_alpha  mean_test_score  mean_train_score
# 0      0.0001         4.312377          4.156141
# 1    0.000158         4.311271          4.156163
# 2    0.000251         4.309698          4.156211
# 3    0.000398         4.307571          4.156307
# 4    0.000631         4.304887          4.156487

# %%
cv_results_.dtypes
# Out:
# param_alpha          object
# mean_test_score     float64
# mean_train_score    float64
# dtype: object

# %%
cv_results_["param_alpha"] = cv_results_["param_alpha"].astype(float)

# %%
cv_results_.set_index("param_alpha").loc[[optimo.alfa, gs.best_params_["alpha"]]]
# Out:
#              mean_test_score  mean_train_score
# param_alpha
# 0.039811            4.285365          4.159901
# 1584.893192         4.220708          4.169354

# %%
sns.lineplot(x="param_alpha", y="mean_test_score", data=cv_results_, label="Test")
sns.lineplot(x="param_alpha", y="mean_train_score", data=cv_results_, label="Train")
plt.xscale("log")
plt.show()

# %%
mejor = gs.best_estimator_
mostrar_rmse(mejor, X_train4, y_train, model_matrix(formula, X_test), y_test)
# Out:
# # RMSE
# Train: 4.1786
# Test:  4.1580

# %%
formula_real = "~ poly(a, 2, raw=True) + poly(b, 2, raw=True) + a:b"
X_real = model_matrix(formula_real, data=X_train)
lr_real = LinearRegression()
lr_real.fit(X_real, y_train)
mostrar_rmse(lr_real, X_real, y_train, model_matrix(formula_real, X_test), y_test)
# Out:
# # RMSE
# Train: 4.1979
# Test:  4.0513

# %%
betas(lr_real, X_real).round(3)
# Out:
# Intercept   -0.489
# a            2.978
# a^2         -0.801
# b           -1.659
# b^2          0.581
# a:b          1.504
# dtype: float64

# %% [markdown]
# Los coeficientes originales eran:
# $$ z = 1 + 3x - 2y + 1.5 xy - 0.8 x^2 - 0.6 y^2 + \epsilon$$
#
# Entonces, ¿es cierta la hipótesis? ¿Da lo mismo un modelo "genérico" con regularización que un modelo "ad-hoc"? ¿En qué tipo de tareas?

# %% [markdown]
# ## Consigna
#
# Cargue el dataset `wine` de scikit-learn, e intente predecir el contenido de alcohol (`alcohol`) de cada vino, usando las características a su disposición, usando una regresión Ridge sobre una matriz de diseño sesudamente construida.
#
# NOTA: El dataset está preparado para utilizarlo en problemas de clasificación, así que tendrá que trocar el objetivo ("target") con la variable predictora "alcohol". Note que la etiqueta del vino peude ser de utilidad en el diseño del modelo.

# %%
from sklearn.datasets import load_wine

wine = load_wine(as_frame=True)

# %%
dir(wine)  # estos son los atributos del objeto, exprorelos!
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
wine.data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %% [markdown]
# Vamos a dividir nuestra base de datos en 20-80, como hacemos siempre

# %% [markdown]
# Necesitamos obtener el alpha mas optimo para nuestro modelo.
#
# Esto se obtiene usando Grid Search de nuestra base de datos.

# %%
test_split = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_split)

# %%
alphas = np.logspace(-3, 3, 61)
alphas
# Out:
# array([1.00000000e-03, 1.25892541e-03, 1.58489319e-03, 1.99526231e-03,
#        2.51188643e-03, 3.16227766e-03, 3.98107171e-03, 5.01187234e-03,
#        6.30957344e-03, 7.94328235e-03, 1.00000000e-02, 1.25892541e-02,
#        1.58489319e-02, 1.99526231e-02, 2.51188643e-02, 3.16227766e-02,
#        3.98107171e-02, 5.01187234e-02, 6.30957344e-02, 7.94328235e-02,
#        1.00000000e-01, 1.25892541e-01, 1.58489319e-01, 1.99526231e-01,
#        2.51188643e-01, 3.16227766e-01, 3.98107171e-01, 5.01187234e-01,
#        6.30957344e-01, 7.94328235e-01, 1.00000000e+00, 1.25892541e+00,
#        1.58489319e+00, 1.99526231e+00, 2.51188643e+00, 3.16227766e+00,
#        3.98107171e+00, 5.01187234e+00, 6.30957344e+00, 7.94328235e+00,
#        1.00000000e+01, 1.25892541e+01, 1.58489319e+01, 1.99526231e+01,
#        2.51188643e+01, 3.16227766e+01, 3.98107171e+01, 5.01187234e+01,
#        6.30957344e+01, 7.94328235e+01, 1.00000000e+02, 1.25892541e+02,
#        1.58489319e+02, 1.99526231e+02, 2.51188643e+02, 3.16227766e+02,
#        3.98107171e+02, 5.01187234e+02, 6.30957344e+02, 7.94328235e+02,
#        1.00000000e+03])

# %% [markdown]
# --------
# Ahora usamos el GridSearchCV

# %%
mas_alphas = np.unique(np.concatenate([alphas, np.logspace(-4, 4, 41)]))
param_grid = {"alpha": mas_alfas}
gs = GridSearchCV(
    Ridge(),
    param_grid,
    cv=5,    # Entrenamiento cruzado partido en 4 train ,1 test
    scoring="neg_root_mean_squared_error",
    return_train_score=True,
)
gs.fit(X_train, y_train)

gs.best_params_
# Out:
# {'alpha': 6.309573444801936}

# %% [markdown]
# Obtuvimos alpha = 6.309 como el mejor modelo que minimiza el score.

# %%
cv_results_ = pd.DataFrame(gs.cv_results_)[
    ["param_alpha", "mean_test_score", "mean_train_score"]
]
cv_results_[["mean_test_score", "mean_train_score"]] *= -1

# %%
cv_results_.head()
# Out:
#   param_alpha  mean_test_score  mean_train_score
# 0      0.0001        27.416572          27.17569
# 1    0.000158        27.416572          27.17569
# 2    0.000251        27.416572          27.17569
# 3    0.000398        27.416572          27.17569
# 4    0.000631        27.416572          27.17569

# %% [markdown]
# Aca podemos ver los diferentes valores de Beta en train y luego en test dados estos valores de alphas.
#
# Nos quedaremos siempre con el que tenga menor "mean_test_score"

# %% [markdown]
# Una vez que obtuvimos el elpha mas optimo, necesitamos obtener los Betas mas optimos

# %% [markdown]
# Para eso usamos Ridge (Regresion Grieta)

# %%
X_train
# Out:
#      poly(a, 3, raw=True)[0]  poly(a, 3, raw=True)[1]  \
# 607                 9.953327                99.068710
# 768                18.395041               338.377544
# 822                 4.154432                17.259307
# 518                 7.590989                57.623116
# 837                19.763128               390.581221
# ..                       ...                      ...
# 987                 4.063746                16.514030
# 779                15.736679               247.643061
# 452                14.280828               203.942045
# 422                 3.609588                13.029124
# 638                 2.473762                 6.119500
#
#      poly(a, 3, raw=True)[2]  poly(b, 3, raw=True)[0]  \
# 607               986.063227                 9.917892
# 768              6224.468903                 9.989067
# 822                71.702623                14.337907
# 518               437.416448                12.781738
# 837              7719.106589                15.544834
# ..                       ...                      ...
# 987                67.108823                12.370095
# 779              3897.079321                14.378677
# 452              2912.461238                12.192571
# 422                47.029768                14.361524
# 638                15.138189                12.932790
#
#      poly(b, 3, raw=True)[1]  poly(b, 3, raw=True)[2]  \
# 607                98.364583               975.569312
# 768                99.781464               996.723756
# 822               205.575581              2947.523581
# 518               163.372820              2088.188541
# 837               241.641876              3756.282949
# ..                       ...                      ...
# 987               153.019247              1892.862603
# 779               206.746350              2972.738962
# 452               148.658789              1812.532851
# 422               206.253383              2962.112995
# 638               167.257045              2163.100155
#
#      poly(a, 3, raw=True)[0]:poly(b, 3, raw=True)[0]  \
# 607                                        98.716019
# 768                                       183.749304
# 822                                        59.565864
# 518                                        97.026032
# 837                                       307.214549
# ..                                               ...
# 987                                        50.268922
# 779                                       226.272621
# 452                                       174.120009
# 422                                        51.839184
# 638                                        31.992648
#
#      poly(a, 3, raw=True)[1]:poly(b, 3, raw=True)[0]  \
# 607                                       982.552773
# 768                                      3380.076043
# 822                                       247.462345
# 518                                       736.523558
# 837                                      6071.520395
# ..                                               ...
# 987                                       204.280124
# 779                                      3560.779564
# 452                                      2486.577874
# 422                                       187.118086
# 638                                        79.142207
#
#      poly(a, 3, raw=True)[2]:poly(b, 3, raw=True)[0]  \
# 607                                      9779.668635
# 768                                     62176.638395
# 822                                      1028.065547
# 518                                      5590.942330
# 837                                    119992.233577
# ..                                               ...
# 987                                       830.142508
# 779                                     56034.844438
# 452                                     35510.390615
# 422                                       675.419164
# 638                                       195.779010
#
#      poly(a, 3, raw=True)[0]:poly(b, 3, raw=True)[1]  \
# 607                                       979.054816
# 768                                      1835.484156
# 822                                       854.049822
# 518                                      1240.161302
# 837                                      4775.599285
# ..                                               ...
# 987                                       621.831333
# 779                                      3253.500906
# 452                                      2122.970580
# 422                                       744.489700
# 638                                       413.754177
#
#      poly(a, 3, raw=True)[1]:poly(b, 3, raw=True)[1]  \
# 607                                      9744.852327
# 768                                     33763.806860
# 822                                      3548.092121
# 518                                      9414.050970
# 837                                     94380.779049
# ..                                               ...
# 987                                      2526.964510
# 779                                     51199.298878
# 452                                     30317.777437
# 422                                      2687.300955
# 638                                      1023.529500
#
#      poly(a, 3, raw=True)[2]:poly(b, 3, raw=True)[1]  \
# 607                                     9.699370e+04
# 768                                     6.210866e+05
# 822                                     1.474031e+04
# 518                                     7.146196e+04
# 837                                     1.865259e+06
# ..                                               ...
# 987                                     1.026894e+04
# 779                                     8.057069e+05
# 452                                     4.329630e+05
# 422                                     9.700049e+03
# 638                                     2.531969e+03
#
#      poly(a, 3, raw=True)[0]:poly(b, 3, raw=True)[2]  \
# 607                                      9710.159968
# 768                                     18334.774654
# 822                                     12245.287020
# 518                                     15851.416530
# 837                                     74235.900011
# ..                                               ...
# 987                                      7692.112582
# 779                                     46781.038332
# 452                                     25884.469667
# 422                                     10692.006993
# 638                                      5350.995689
#
#      poly(a, 3, raw=True)[1]:poly(b, 3, raw=True)[2]  \
# 607                                     9.664839e+04
# 768                                     3.372689e+05
# 822                                     5.087222e+04
# 518                                     1.203279e+05
# 837                                     1.467134e+06
# ..                                               ...
# 987                                     3.125879e+04
# 779                                     7.361782e+05
# 452                                     3.696517e+05
# 422                                     3.859374e+04
# 638                                     1.323709e+04
#
#      poly(a, 3, raw=True)[2]:poly(b, 3, raw=True)[2]
# 607                                     9.619730e+05
# 768                                     6.204076e+06
# 822                                     2.113452e+05
# 518                                     9.134080e+05
# 837                                     2.899515e+07
# ..                                               ...
# 987                                     1.270278e+05
# 779                                     1.158500e+07
# 452                                     5.278932e+06
# 422                                     1.393075e+05
# 638                                     3.274542e+04
#
# [800 rows x 15 columns]

# %%
formula_real2 = "~ poly(a, 2, raw=True) + poly(b, 2, raw=True) + a:b"
X_real = model_matrix(formula_real, data=X_train)
lr_real2 = LinearRegression()
lr_real2.fit(X_real, y_train)
mostrar_rmse(lr_real2, X_real, y_train, model_matrix(formula_real2, X_test), y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/formulaic/materializers/base.py in _evaluate_factor(self, factor, spec, drop_rows)
#     520                 if factor.eval_method.value == "lookup":
# --> 521                     value, variables = self._lookup(factor.expr)
#     522                 elif factor.eval_method.value == "python":
#
# ~/.local/lib/python3.10/site-packages/formulaic/materializers/base.py in _lookup(self, name)
#     587         if values is sentinel:
# --> 588             raise NameError(
#     589                 f"`{name}` is not present in the dataset or evaluation context."
#
# NameError: `a` is not present in the dataset or evaluation context.
#
# The above exception was the direct cause of the following exception:
#
# FactorEvaluationError                     Traceback (most recent call last)
# /tmp/ipykernel_23453/2273457862.py in <cell line: 2>()
#       1 formula_real2 = "~ poly(a, 2, raw=True) + poly(b, 2, raw=True) + a:b"
# ----> 2 X_real = model_matrix(formula_real, data=X_train)
#       3 lr_real2 = LinearRegression()
#       4 lr_real2.fit(X_real, y_train)
#       5 mostrar_rmse(lr_real2, X_real, y_train, model_matrix(formula_real2, X_test), y_test)
#
# ~/.local/lib/python3.10/site-packages/formulaic/sugar.py in model_matrix(spec, data, context, **spec_overrides)
#      49     """
#      50     _context = capture_context(context + 1) if isinstance(context, int) else context
# ---> 51     return ModelSpec.from_spec(spec, **spec_overrides).get_model_matrix(
#      52         data, context=_context
#      53     )
#
# ~/.local/lib/python3.10/site-packages/formulaic/model_spec.py in get_model_matrix(self, data, context, **attr_overrides)
#     334         return materializer(
#     335             data, context=context, **(self.materializer_params or {})
# --> 336         ).get_model_matrix(self)
#     337
#     338     def get_linear_constraints(self, spec: LinearConstraintSpec) -> LinearConstraints:
#
# ~/.local/lib/python3.10/site-packages/formulaic/materializers/base.py in get_model_matrix(self, spec, **spec_overrides)
#     180         drop_rows: Set[int] = set()
#     181         for factor in factors:
# --> 182             self._evaluate_factor(factor, factor_evaluation_model_spec, drop_rows)
#     183         drop_rows: Sequence[int] = sorted(drop_rows)
#     184
#
# ~/.local/lib/python3.10/site-packages/formulaic/materializers/base.py in _evaluate_factor(self, factor, spec, drop_rows)
#     538                 raise
#     539             except Exception as e:
# --> 540                 raise FactorEvaluationError(
#     541                     f"Unable to evaluate factor `{factor}`. [{type(e).__name__}: {e}]"
#     542                 ) from e
#
# FactorEvaluationError: Unable to evaluate factor `a`. [NameError: `a` is not present in the dataset or evaluation context.]
