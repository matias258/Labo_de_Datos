# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so
from gapminder import gapminder

# %% [markdown]
# # Ej 1

# %% [markdown]
# ## a)
#
# Ejecutar el siguiente codigo y observar si hay filas con datos faltantes (NaN)

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Si hay, ya podemos ver un NaN en 3.

# %%
penguins.isnull().values.any()
# Out:
# True

# %%
penguins = penguins.dropna()
display(penguins)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
penguins.shape
# Out:
# (333, 7)

# %%
# Consigo el 20%
test = penguins.shape[0] * 20 / 100 

# lo redondeo
test = int(test)
print(test)

# recordar sumar 1 al train, asi no desaprovecho una fila.
# Out:
# 66

# %% [markdown]
# ## b)

# %% [markdown]
# ### A -> Utilizando un array de Numpy para filtrar

# %%
# creo array del mismo tamaño que el database, todos con valor False
train_ind = np.full(penguins.shape[0], False) 

# Cambio los 1ros 80% a True
train_ind[0:penguins.shape[0] - test] = True

np.random.shuffle(train_ind) # Lo guarda el mismo vector

# Selecciono de penguins los que su indice coinciden con que train_ind == True, garantizandome una eleccion al azar de train
penguins_train2 = penguins[train_ind == True]

# Lo mismo pero con False para los de test%
penguins_test2 = penguins[train_ind == False]

# %%
display(train_ind)
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#        False, False,  True,  True,  True, False,  True,  True, False,
#        False,  True,  True, False,  True, False, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#        False,  True,  True,  True, False, False,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False, False,  True,  True,  True,
#         True, False, False,  True, False, False, False,  True,  True,
#         True,  True,  True, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True,  True, False,  True, False,  True,  True,
#         True,  True,  True,  True, False, False, False,  True,  True,
#        False,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False,  True, False,  True, False, False,  True, False,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#        False,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#        False,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True, False,  True, False,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True, False])

# %%
display(penguins_train2)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 337  Gentoo     Biscoe            48.8           16.2              222.0
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 335       5850.0    Male
# 337       6000.0    Male
# 338       4925.0  Female
# 340       4850.0  Female
# 342       5200.0  Female
#
# [267 rows x 7 columns]

# %%
display(penguins_test2)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 15   Adelie  Torgersen            36.6           17.8              185.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 22   Adelie     Biscoe            35.9           19.2              189.0
# ..      ...        ...             ...            ...                ...
# 325  Gentoo     Biscoe            46.8           16.1              215.0
# 327  Gentoo     Biscoe            53.4           15.8              219.0
# 330  Gentoo     Biscoe            50.5           15.2              216.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 7         4675.0    Male
# 14        4400.0    Male
# 15        3700.0  Female
# 19        4200.0    Male
# 22        3800.0  Female
# ..           ...     ...
# 325       5500.0    Male
# 327       5500.0    Male
# 330       5000.0  Female
# 341       5750.0    Male
# 343       5400.0    Male
#
# [66 rows x 7 columns]

# %% [markdown]
# ### B -> train_test_split de sklearn

# %%
from sklearn.model_selection import train_test_split
penguins_train, penguins_test = train_test_split(penguins, test_size = 0.2, random_state = 42)

# %%
display(penguins_test)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie      Dream            39.5           16.7              178.0
# 317     Gentoo     Biscoe            46.9           14.6              222.0
# 79      Adelie  Torgersen            42.1           19.1              195.0
# 201  Chinstrap      Dream            49.8           17.3              198.0
# 63      Adelie     Biscoe            41.1           18.2              192.0
# ..         ...        ...             ...            ...                ...
# 288     Gentoo     Biscoe            43.5           14.2              220.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 83      Adelie  Torgersen            35.1           19.4              193.0
# 319     Gentoo     Biscoe            51.1           16.5              225.0
# 66      Adelie     Biscoe            35.5           16.2              195.0
#
#      body_mass_g     sex
# 30        3250.0  Female
# 317       4875.0  Female
# 79        4000.0    Male
# 201       3675.0  Female
# 63        4050.0    Male
# ..           ...     ...
# 288       4700.0  Female
# 4         3450.0  Female
# 83        4200.0    Male
# 319       5250.0    Male
# 66        3350.0  Female
#
# [67 rows x 7 columns]

# %%
display(penguins_train)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 230     Gentoo     Biscoe            40.9           13.7              214.0
# 84      Adelie      Dream            37.3           17.8              191.0
# 303     Gentoo     Biscoe            50.0           15.9              224.0
# 22      Adelie     Biscoe            35.9           19.2              189.0
# 29      Adelie     Biscoe            40.5           18.9              180.0
# ..         ...        ...             ...            ...                ...
# 194  Chinstrap      Dream            50.9           19.1              196.0
# 77      Adelie  Torgersen            37.2           19.4              184.0
# 112     Adelie     Biscoe            39.7           17.7              193.0
# 277     Gentoo     Biscoe            45.5           15.0              220.0
# 108     Adelie     Biscoe            38.1           17.0              181.0
#
#      body_mass_g     sex
# 230       4650.0  Female
# 84        3350.0  Female
# 303       5350.0    Male
# 22        3800.0  Female
# 29        3950.0    Male
# ..           ...     ...
# 194       3550.0    Male
# 77        3900.0    Male
# 112       3200.0  Female
# 277       5000.0    Male
# 108       3175.0  Female
#
# [266 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# Quito la columna "species" para obtener las caracteristicas 
x = penguins.drop("species", axis = 1)

# Utilizo la columna "species" como nuestra variable objetivo
y = penguins["species"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
display(y_train)
# Out:
# 230       Gentoo
# 84        Adelie
# 303       Gentoo
# 22        Adelie
# 29        Adelie
#          ...
# 194    Chinstrap
# 77        Adelie
# 112       Adelie
# 277       Gentoo
# 108       Adelie
# Name: species, Length: 266, dtype: object

# %% [markdown]
# ## c )
#
# Crear y ajustar 3 modelos utilizando polinomios de grados 1, 2 y 3

# %%
from sklearn.model_selection import train_test_split
penguins_train, penguin_test = train_test_split(penguins, test_size = 0.2, random_state = 42)

# %%
penguins_train.head()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 230  Gentoo  Biscoe            40.9           13.7              214.0
# 84   Adelie   Dream            37.3           17.8              191.0
# 303  Gentoo  Biscoe            50.0           15.9              224.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 29   Adelie  Biscoe            40.5           18.9              180.0
#
#      body_mass_g     sex
# 230       4650.0  Female
# 84        3350.0  Female
# 303       5350.0    Male
# 22        3800.0  Female
# 29        3950.0    Male

# %%
penguin_test.head()
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie      Dream            39.5           16.7              178.0
# 317     Gentoo     Biscoe            46.9           14.6              222.0
# 79      Adelie  Torgersen            42.1           19.1              195.0
# 201  Chinstrap      Dream            49.8           17.3              198.0
# 63      Adelie     Biscoe            41.1           18.2              192.0
#
#      body_mass_g     sex
# 30        3250.0  Female
# 317       4875.0  Female
# 79        4000.0    Male
# 201       3675.0  Female
# 63        4050.0    Male

# %% [markdown]
# # Ej 2

# %% [markdown]
# ## a)
#
# Realizar un grafico de dispersion para cada par de variables

# %%
startups = pd.read_csv("50_Startups.csv")
sns.pairplot(
    data = startups, aspect = .8
)

# %% [markdown]
# Si quisieramos predecir la ganancia mediante un modelo lineal utilizando una sola variable predictora, ¿Cuál variable utilizaría?
#
# Diseñe un experimento para verificar su respuesta

# %% [markdown]
# - Tan solo viendo el grafico de "Investigacion" x "Ganancia" (abajo izquierda) podriamos generar una regresion lineal para predecir futuros resultados, ya que logramos ver una similitud a una recta.

# %%
startups.head()
# Out:
#    Investigacion  Administracion  Marketing      Estado   Ganancia
# 0      165349.20       136897.80  471784.10    New York  192261.83
# 1      162597.70       151377.59  443898.53  California  191792.06
# 2      153441.51       101145.55  407934.54     Florida  191050.39
# 3      144372.41       118671.85  383199.62    New York  182901.99
# 4      142107.34        91391.77  366168.42     Florida  166187.94

# %%
# Generamos la regresion lineal para "Investigacion" y "Ganancia"

(
    so.Plot(data=startups, x='Investigacion', y='Ganancia')
    .add(so.Dot())
    .add(so.Line(color='red', linewidth=2), so.PolyFit(1), label='Regresion lineal')
)

# %% [markdown]
# ## b)
#
# ¿Considera que un modelo lineal multivariado ayudaria a predecir mejor la ganancia que el modelo lineal univariado del item anterior?
#
# Realizar un experimento para verificar su respuesta.

# %% [markdown]
# En un modelo lineal multivariado estariamos obteniendo datos de multiples grafos a la vez, dandonos una precision mayor que el modelo lineal univariado utilizado en a).
#
# Entonces, creo que crear este modelo nos ayudará a mejorar la precisión de la ganancia en general.

# %%
# !pip install formulaic
# Out:
# WARNING: Ignoring invalid distribution ~orch (/home/matias/anaconda3/lib/python3.11/site-packages)
# Requirement already satisfied: formulaic in /home/matias/anaconda3/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /home/matias/anaconda3/lib/python3.11/site-packages (from formulaic) (1.3.0)
# Requirement already satisfied: numpy>=1.16.5 in /home/matias/anaconda3/lib/python3.11/site-packages (from formulaic) (1.26.4)
# Requirement already satisfied: pandas>=1.0 in /home/matias/anaconda3/lib/python3.11/site-packages (from formulaic) (2.2.1)
# Requirement already satisfied: scipy>=1.6 in /home/matias/anaconda3/lib/python3.11/site-packages (from formulaic) (1.13.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/matias/anaconda3/lib/python3.11/site-packages (from formulaic) (4.10.0)
# Requirement already satisfied: wrapt>=1.0 in /home/matias/anaconda3/lib/python3.11/site-packages (from formulaic) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/matias/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->formulaic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/matias/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->formulaic) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/matias/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->formulaic) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/matias/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.0->formulaic) (1.16.0)
# WARNING: Ignoring invalid distribution ~orch (/home/matias/anaconda3/lib/python3.11/site-packages)

# %%
from formulaic import model_matrix

# %%
startups.head()
# Out:
#    Investigacion  Administracion  Marketing      Estado   Ganancia
# 0      165349.20       136897.80  471784.10    New York  192261.83
# 1      162597.70       151377.59  443898.53  California  191792.06
# 2      153441.51       101145.55  407934.54     Florida  191050.39
# 3      144372.41       118671.85  383199.62    New York  182901.99
# 4      142107.34        91391.77  366168.42     Florida  166187.94

# %%
df = startups

# Definimos y = Ganancia como variable objetivo
# Definimos x = "Administracion", "Marketing", "Estado", e "Investigacion" las variables predictoras.
y, x = model_matrix("Ganancia ~ Administracion + Marketing + Estado + Investigacion", df)
pd.concat([y, x], axis = 1)

# ~ = "Separates the target features from the input features." 
# + = "Adds a new term to the set of features." (segun bibliografia)
# Out:
#      Ganancia  Intercept  Administracion  Marketing  Estado[T.Florida]  \
# 0   192261.83        1.0       136897.80  471784.10                  0
# 1   191792.06        1.0       151377.59  443898.53                  0
# 2   191050.39        1.0       101145.55  407934.54                  1
# 3   182901.99        1.0       118671.85  383199.62                  0
# 4   166187.94        1.0        91391.77  366168.42                  1
# 5   156991.12        1.0        99814.71  362861.36                  0
# 6   156122.51        1.0       147198.87  127716.82                  0
# 7   155752.60        1.0       145530.06  323876.68                  1
# 8   152211.77        1.0       148718.95  311613.29                  0
# 9   149759.96        1.0       108679.17  304981.62                  0
# 10  146121.95        1.0       110594.11  229160.95                  1
# 11  144259.40        1.0        91790.61  249744.55                  0
# 12  141585.52        1.0       127320.38  249839.44                  1
# 13  134307.35        1.0       135495.07  252664.93                  0
# 14  132602.65        1.0       156547.42  256512.92                  1
# 15  129917.04        1.0       122616.84  261776.23                  0
# 16  126992.93        1.0       121597.55  264346.06                  0
# 17  125370.37        1.0       145077.58  282574.31                  0
# 18  124266.90        1.0       114175.79  294919.57                  1
# 19  122776.86        1.0       153514.11       0.00                  0
# 20  118474.03        1.0       113867.30  298664.47                  0
# 21  111313.02        1.0       153773.43  299737.29                  0
# 22  110352.25        1.0       122782.75  303319.26                  1
# 23  108733.99        1.0       105751.03  304768.73                  1
# 24  108552.04        1.0        99281.34  140574.81                  0
# 25  107404.34        1.0       139553.16  137962.62                  0
# 26  105733.54        1.0       144135.98  134050.07                  1
# 27  105008.31        1.0       127864.55  353183.81                  0
# 28  103282.38        1.0       182645.56  118148.20                  1
# 29  101004.64        1.0       153032.06  107138.38                  0
# 30   99937.59        1.0       115641.28   91131.24                  1
# 31   97483.56        1.0       152701.92   88218.23                  0
# 32   97427.84        1.0       129219.61   46085.25                  0
# 33   96778.92        1.0       103057.49  214634.81                  1
# 34   96712.80        1.0       157693.92  210797.67                  0
# 35   96479.51        1.0        85047.44  205517.64                  0
# 36   90708.19        1.0       127056.21  201126.82                  1
# 37   89949.14        1.0        51283.14  197029.42                  0
# 38   81229.06        1.0        65947.93  185265.10                  0
# 39   81005.76        1.0        82982.09  174999.30                  0
# 40   78239.91        1.0       118546.05  172795.67                  0
# 41   77798.83        1.0        84710.77  164470.71                  1
# 42   71498.49        1.0        96189.63  148001.11                  0
# 43   69758.98        1.0       127382.30   35534.17                  0
# 44   65200.33        1.0       154806.14   28334.72                  0
# 45   64926.08        1.0       124153.04    1903.93                  0
# 46   49490.75        1.0       115816.21  297114.46                  1
# 47   42559.73        1.0       135426.92       0.00                  0
# 48   35673.41        1.0        51743.15       0.00                  0
# 49   14681.40        1.0       116983.80   45173.06                  0
#
#     Estado[T.New York]  Investigacion
# 0                    1      165349.20
# 1                    0      162597.70
# 2                    0      153441.51
# 3                    1      144372.41
# 4                    0      142107.34
# 5                    1      131876.90
# 6                    0      134615.46
# 7                    0      130298.13
# 8                    1      120542.52
# 9                    0      123334.88
# 10                   0      101913.08
# 11                   0      100671.96
# 12                   0       93863.75
# 13                   0       91992.39
# 14                   0      119943.24
# 15                   1      114523.61
# 16                   0       78013.11
# 17                   1       94657.16
# 18                   0       91749.16
# 19                   1       86419.70
# 20                   0       76253.86
# 21                   1       78389.47
# 22                   0       73994.56
# 23                   0       67532.53
# 24                   1       77044.01
# 25                   0       64664.71
# 26                   0       75328.87
# 27                   1       72107.60
# 28                   0       66051.52
# 29                   1       65605.48
# 30                   0       61994.48
# 31                   1       61136.38
# 32                   0       63408.86
# 33                   0       55493.95
# 34                   0       46426.07
# 35                   1       46014.02
# 36                   0       28663.76
# 37                   0       44069.95
# 38                   1       20229.59
# 39                   0       38558.51
# 40                   0       28754.33
# 41                   0       27892.92
# 42                   0       23640.93
# 43                   1       15505.73
# 44                   0       22177.74
# 45                   1        1000.23
# 46                   0        1315.46
# 47                   0           0.00
# 48                   1         542.05
# 49                   0           0.00

# %% [markdown]
# ## Terminar b)
