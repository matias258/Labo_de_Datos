# %%
import seaborn as sns
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

from scipy import stats
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from formulaic import model_matrix

# %% [markdown]
# # Ej 1: Crear subconj de datos que contenga solo los pinguinos de la isla Biscoe y que tengan un pico de 48 mm de largo o mas
#
#
# recordar "bill_depth_mm" = pico del pinguino

# %%
penguins = sns.load_dataset("penguins")
penguinsClean = penguins.dropna()
penguinsClean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
biscoe = penguinsClean[penguinsClean.island == "Biscoe"]
biscoe
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie  Biscoe            37.8           18.3              174.0
# 21   Adelie  Biscoe            37.7           18.7              180.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 23   Adelie  Biscoe            38.2           18.1              185.0
# 24   Adelie  Biscoe            38.8           17.2              180.0
# ..      ...     ...             ...            ...                ...
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 20        3400.0  Female
# 21        3600.0    Male
# 22        3800.0  Female
# 23        3950.0    Male
# 24        3800.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [163 rows x 7 columns]

# %%
granPico = biscoe[biscoe['flipper_length_mm'] >= 48]
granPico.reset_index()
# Out:
#      index species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       20  Adelie  Biscoe            37.8           18.3              174.0
# 1       21  Adelie  Biscoe            37.7           18.7              180.0
# 2       22  Adelie  Biscoe            35.9           19.2              189.0
# 3       23  Adelie  Biscoe            38.2           18.1              185.0
# 4       24  Adelie  Biscoe            38.8           17.2              180.0
# ..     ...     ...     ...             ...            ...                ...
# 158    338  Gentoo  Biscoe            47.2           13.7              214.0
# 159    340  Gentoo  Biscoe            46.8           14.3              215.0
# 160    341  Gentoo  Biscoe            50.4           15.7              222.0
# 161    342  Gentoo  Biscoe            45.2           14.8              212.0
# 162    343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3400.0  Female
# 1         3600.0    Male
# 2         3800.0  Female
# 3         3950.0    Male
# 4         3800.0    Male
# ..           ...     ...
# 158       4925.0  Female
# 159       4850.0  Female
# 160       5750.0    Male
# 161       5200.0  Female
# 162       5400.0    Male
#
# [163 rows x 8 columns]

# %%
# Intentemos hacerlo en 1 lista de comprension

picos = penguinsClean[(penguinsClean.island == "Biscoe") & (penguinsClean.flipper_length_mm >= 48)]
picos.reset_index()
# Out:
#      index species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       20  Adelie  Biscoe            37.8           18.3              174.0
# 1       21  Adelie  Biscoe            37.7           18.7              180.0
# 2       22  Adelie  Biscoe            35.9           19.2              189.0
# 3       23  Adelie  Biscoe            38.2           18.1              185.0
# 4       24  Adelie  Biscoe            38.8           17.2              180.0
# ..     ...     ...     ...             ...            ...                ...
# 158    338  Gentoo  Biscoe            47.2           13.7              214.0
# 159    340  Gentoo  Biscoe            46.8           14.3              215.0
# 160    341  Gentoo  Biscoe            50.4           15.7              222.0
# 161    342  Gentoo  Biscoe            45.2           14.8              212.0
# 162    343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3400.0  Female
# 1         3600.0    Male
# 2         3800.0  Female
# 3         3950.0    Male
# 4         3800.0    Male
# ..           ...     ...
# 158       4925.0  Female
# 159       4850.0  Female
# 160       5750.0    Male
# 161       5200.0  Female
# 162       5400.0    Male
#
# [163 rows x 8 columns]

# %%
picos.equals(granPico)
# Son los mismos
# Out:
# True

# %% [markdown]
# # Ej 2: Crear otro dataset con la info de pinguinos Adelie machos que no sean de Biscoe

# %%
pingu = penguinsClean[(penguinsClean.sex == "Male") & (penguinsClean.island != "Biscoe") & (penguinsClean.species == "Adelie")]
pingu.reset_index()
# Out:
#     index species     island  bill_length_mm  bill_depth_mm  \
# 0       0  Adelie  Torgersen            39.1           18.7
# 1       5  Adelie  Torgersen            39.3           20.6
# 2       7  Adelie  Torgersen            39.2           19.6
# 3      13  Adelie  Torgersen            38.6           21.2
# 4      14  Adelie  Torgersen            34.6           21.1
# 5      17  Adelie  Torgersen            42.5           20.7
# 6      19  Adelie  Torgersen            46.0           21.5
# 7      31  Adelie      Dream            37.2           18.1
# 8      33  Adelie      Dream            40.9           18.9
# 9      35  Adelie      Dream            39.2           21.1
# 10     36  Adelie      Dream            38.8           20.0
# 11     39  Adelie      Dream            39.8           19.1
# 12     41  Adelie      Dream            40.8           18.4
# 13     43  Adelie      Dream            44.1           19.7
# 14     45  Adelie      Dream            39.6           18.8
# 15     46  Adelie      Dream            41.1           19.0
# 16     49  Adelie      Dream            42.3           21.2
# 17     69  Adelie  Torgersen            41.8           19.4
# 18     71  Adelie  Torgersen            39.7           18.4
# 19     73  Adelie  Torgersen            45.8           18.9
# 20     75  Adelie  Torgersen            42.8           18.5
# 21     77  Adelie  Torgersen            37.2           19.4
# 22     79  Adelie  Torgersen            42.1           19.1
# 23     81  Adelie  Torgersen            42.9           17.6
# 24     83  Adelie  Torgersen            35.1           19.4
# 25     85  Adelie      Dream            41.3           20.3
# 26     86  Adelie      Dream            36.3           19.5
# 27     88  Adelie      Dream            38.3           19.2
# 28     91  Adelie      Dream            41.1           18.1
# 29     93  Adelie      Dream            39.6           18.1
# 30     95  Adelie      Dream            40.8           18.9
# 31     97  Adelie      Dream            40.3           18.5
# 32     99  Adelie      Dream            43.2           18.5
# 33    117  Adelie  Torgersen            37.3           20.5
# 34    119  Adelie  Torgersen            41.1           18.6
# 35    121  Adelie  Torgersen            37.7           19.8
# 36    123  Adelie  Torgersen            41.4           18.5
# 37    125  Adelie  Torgersen            40.6           19.0
# 38    127  Adelie  Torgersen            41.5           18.3
# 39    129  Adelie  Torgersen            44.1           18.0
# 40    131  Adelie  Torgersen            43.1           19.2
# 41    133  Adelie      Dream            37.5           18.5
# 42    135  Adelie      Dream            41.1           17.5
# 43    137  Adelie      Dream            40.2           20.1
# 44    139  Adelie      Dream            39.7           17.9
# 45    141  Adelie      Dream            40.6           17.2
# 46    143  Adelie      Dream            40.7           17.0
# 47    145  Adelie      Dream            39.0           18.7
# 48    146  Adelie      Dream            39.2           18.6
# 49    149  Adelie      Dream            37.8           18.1
# 50    151  Adelie      Dream            41.5           18.5
#
#     flipper_length_mm  body_mass_g   sex
# 0               181.0       3750.0  Male
# 1               190.0       3650.0  Male
# 2               195.0       4675.0  Male
# 3               191.0       3800.0  Male
# 4               198.0       4400.0  Male
# 5               197.0       4500.0  Male
# 6               194.0       4200.0  Male
# 7               178.0       3900.0  Male
# 8               184.0       3900.0  Male
# 9               196.0       4150.0  Male
# 10              190.0       3950.0  Male
# 11              184.0       4650.0  Male
# 12              195.0       3900.0  Male
# 13              196.0       4400.0  Male
# 14              190.0       4600.0  Male
# 15              182.0       3425.0  Male
# 16              191.0       4150.0  Male
# 17              198.0       4450.0  Male
# 18              190.0       3900.0  Male
# 19              197.0       4150.0  Male
# 20              195.0       4250.0  Male
# 21              184.0       3900.0  Male
# 22              195.0       4000.0  Male
# 23              196.0       4700.0  Male
# 24              193.0       4200.0  Male
# 25              194.0       3550.0  Male
# 26              190.0       3800.0  Male
# 27              189.0       3950.0  Male
# 28              205.0       4300.0  Male
# 29              186.0       4450.0  Male
# 30              208.0       4300.0  Male
# 31              196.0       4350.0  Male
# 32              192.0       4100.0  Male
# 33              199.0       3775.0  Male
# 34              189.0       3325.0  Male
# 35              198.0       3500.0  Male
# 36              202.0       3875.0  Male
# 37              199.0       4000.0  Male
# 38              195.0       4300.0  Male
# 39              210.0       4000.0  Male
# 40              197.0       3500.0  Male
# 41              199.0       4475.0  Male
# 42              190.0       3900.0  Male
# 43              200.0       3975.0  Male
# 44              193.0       4250.0  Male
# 45              187.0       3475.0  Male
# 46              190.0       3725.0  Male
# 47              185.0       3650.0  Male
# 48              190.0       4250.0  Male
# 49              193.0       3750.0  Male
# 50              201.0       4000.0  Male

# %% [markdown]
# # Ej 3: Del dataset penguins quedarse con todas las variables excepto year, sex, y body_mass_g

# %%
# | = Alt Gr + 1 
nuevo_penguins = penguinsClean[penguinsClean.columns[~penguinsClean.columns.isin(["year", "sex", "body_mass_g"])]]
nuevo_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
# [333 rows x 5 columns]

# %% [markdown]
# # Ej 4: Restablecer Indices

# %% [markdown]
# ## a) En el dataset penguins, eliminar 1ro todas las filas con datos faltantes, ¿Que sucede con los indices?

# %%
penguins_limpio = penguins.dropna()
penguins_limpio
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# - Los indices estan mal enumerados

# %% [markdown]
# ## b) Restablecer indices

# %%
# los corregimos

penguins_limpio.reset_index()
# Out:
#      index species     island  bill_length_mm  bill_depth_mm  \
# 0        0  Adelie  Torgersen            39.1           18.7
# 1        1  Adelie  Torgersen            39.5           17.4
# 2        2  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen            36.7           19.3
# 4        5  Adelie  Torgersen            39.3           20.6
# ..     ...     ...        ...             ...            ...
# 328    338  Gentoo     Biscoe            47.2           13.7
# 329    340  Gentoo     Biscoe            46.8           14.3
# 330    341  Gentoo     Biscoe            50.4           15.7
# 331    342  Gentoo     Biscoe            45.2           14.8
# 332    343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    Male
# 1                186.0       3800.0  Female
# 2                195.0       3250.0  Female
# 3                193.0       3450.0  Female
# 4                190.0       3650.0    Male
# ..                 ...          ...     ...
# 328              214.0       4925.0  Female
# 329              215.0       4850.0  Female
# 330              222.0       5750.0    Male
# 331              212.0       5200.0  Female
# 332              213.0       5400.0    Male
#
# [333 rows x 8 columns]

# %% [markdown]
# ## c) Encadenar comandos

# %%
# veamos como hacer todo en un comando

penguins_limpio2 = penguins.dropna().reset_index()
penguins_limpio2
# Out:
#      index species     island  bill_length_mm  bill_depth_mm  \
# 0        0  Adelie  Torgersen            39.1           18.7
# 1        1  Adelie  Torgersen            39.5           17.4
# 2        2  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen            36.7           19.3
# 4        5  Adelie  Torgersen            39.3           20.6
# ..     ...     ...        ...             ...            ...
# 328    338  Gentoo     Biscoe            47.2           13.7
# 329    340  Gentoo     Biscoe            46.8           14.3
# 330    341  Gentoo     Biscoe            50.4           15.7
# 331    342  Gentoo     Biscoe            45.2           14.8
# 332    343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    Male
# 1                186.0       3800.0  Female
# 2                195.0       3250.0  Female
# 3                193.0       3450.0  Female
# 4                190.0       3650.0    Male
# ..                 ...          ...     ...
# 328              214.0       4925.0  Female
# 329              215.0       4850.0  Female
# 330              222.0       5750.0    Male
# 331              212.0       5200.0  Female
# 332              213.0       5400.0    Male
#
# [333 rows x 8 columns]

# %%
penguins_limpio2.equals(penguins_limpio) # False, ¿Huh?
# Out:
# False

# %% [markdown]
# # 5. Renombrar columnas e indices

# %% [markdown]
# ## a) Renombrar la variable "species" a "especies"

# %%
penguinsClean.rename(columns = {"species": "especies"})
# Out:
#     especies     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0     Adelie  Torgersen            39.1           18.7              181.0
# 1     Adelie  Torgersen            39.5           17.4              186.0
# 2     Adelie  Torgersen            40.3           18.0              195.0
# 4     Adelie  Torgersen            36.7           19.3              193.0
# 5     Adelie  Torgersen            39.3           20.6              190.0
# ..       ...        ...             ...            ...                ...
# 338   Gentoo     Biscoe            47.2           13.7              214.0
# 340   Gentoo     Biscoe            46.8           14.3              215.0
# 341   Gentoo     Biscoe            50.4           15.7              222.0
# 342   Gentoo     Biscoe            45.2           14.8              212.0
# 343   Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## b) Renombrar en un solo rename la variable "flipper_length_mm" a "aleta_mm" y "body_mass_g" a "peso_g"

# %%
penguinsClean.rename(columns = {"flipper_length_mm": "aleta_mm" , "body_mass_g":"peso_g"})
# Out:
#     species     island  bill_length_mm  bill_depth_mm  aleta_mm  peso_g  \
# 0    Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 1    Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 2    Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 4    Adelie  Torgersen            36.7           19.3     193.0  3450.0
# 5    Adelie  Torgersen            39.3           20.6     190.0  3650.0
# ..      ...        ...             ...            ...       ...     ...
# 338  Gentoo     Biscoe            47.2           13.7     214.0  4925.0
# 340  Gentoo     Biscoe            46.8           14.3     215.0  4850.0
# 341  Gentoo     Biscoe            50.4           15.7     222.0  5750.0
# 342  Gentoo     Biscoe            45.2           14.8     212.0  5200.0
# 343  Gentoo     Biscoe            49.9           16.1     213.0  5400.0
#
#         sex
# 0      Male
# 1    Female
# 2    Female
# 4    Female
# 5      Male
# ..      ...
# 338  Female
# 340  Female
# 341    Male
# 342  Female
# 343    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## c) Renombrar el indice 0 a "cero"

# %%
penguinsClean.rename(index = {0: "cero"})
# Out:
#      species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# cero  Adelie  Torgersen            39.1           18.7              181.0
# 1     Adelie  Torgersen            39.5           17.4              186.0
# 2     Adelie  Torgersen            40.3           18.0              195.0
# 4     Adelie  Torgersen            36.7           19.3              193.0
# 5     Adelie  Torgersen            39.3           20.6              190.0
# ...      ...        ...             ...            ...                ...
# 338   Gentoo     Biscoe            47.2           13.7              214.0
# 340   Gentoo     Biscoe            46.8           14.3              215.0
# 341   Gentoo     Biscoe            50.4           15.7              222.0
# 342   Gentoo     Biscoe            45.2           14.8              212.0
# 343   Gentoo     Biscoe            49.9           16.1              213.0
#
#       body_mass_g     sex
# cero       3750.0    Male
# 1          3800.0  Female
# 2          3250.0  Female
# 4          3450.0  Female
# 5          3650.0    Male
# ...           ...     ...
# 338        4925.0  Female
# 340        4850.0  Female
# 341        5750.0    Male
# 342        5200.0  Female
# 343        5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## d) Pasar todos los nombres de variables a mayusculas.

# %%
penguinsClean.rename(columns = str.upper)
# Out:
#     SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      BODY_MASS_G     SEX
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## e) ¿Que esperamos de este comando?

# %%
penguinsClean.rename(index = np.sqrt)
# Me imagino que se rompe, pues sqrt(cero) no se puede hacer
# Out:
#           species     island  bill_length_mm  bill_depth_mm  \
# 0.000000   Adelie  Torgersen            39.1           18.7
# 1.000000   Adelie  Torgersen            39.5           17.4
# 1.414214   Adelie  Torgersen            40.3           18.0
# 2.000000   Adelie  Torgersen            36.7           19.3
# 2.236068   Adelie  Torgersen            39.3           20.6
# ...           ...        ...             ...            ...
# 18.384776  Gentoo     Biscoe            47.2           13.7
# 18.439089  Gentoo     Biscoe            46.8           14.3
# 18.466185  Gentoo     Biscoe            50.4           15.7
# 18.493242  Gentoo     Biscoe            45.2           14.8
# 18.520259  Gentoo     Biscoe            49.9           16.1
#
#            flipper_length_mm  body_mass_g     sex
# 0.000000               181.0       3750.0    Male
# 1.000000               186.0       3800.0  Female
# 1.414214               195.0       3250.0  Female
# 2.000000               193.0       3450.0  Female
# 2.236068               190.0       3650.0    Male
# ...                      ...          ...     ...
# 18.384776              214.0       4925.0  Female
# 18.439089              215.0       4850.0  Female
# 18.466185              222.0       5750.0    Male
# 18.493242              212.0       5200.0  Female
# 18.520259              213.0       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# Me equivoque, nos devuelve la raiz de cada indice

# %% [markdown]
# ## f) ¿Como podemos sumarle uno a todos los indices de penguins?

# %%
def suma_uno(x):
    x = x + 1
    return(x)

penguinsClean.rename(index = lambda index : suma_uno(index))
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 5    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            47.2           13.7              214.0
# 341  Gentoo     Biscoe            46.8           14.3              215.0
# 342  Gentoo     Biscoe            50.4           15.7              222.0
# 343  Gentoo     Biscoe            45.2           14.8              212.0
# 344  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 1         3750.0    Male
# 2         3800.0  Female
# 3         3250.0  Female
# 5         3450.0  Female
# 6         3650.0    Male
# ..           ...     ...
# 339       4925.0  Female
# 341       4850.0  Female
# 342       5750.0    Male
# 343       5200.0  Female
# 344       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## g) Que esperamos de este resultado?

# %%
penguinsClean.rename(index = lambda x : x * 2)

# Esperamos que cada indice sea multiplicado por 2
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            39.5           17.4              186.0
# 4    Adelie  Torgersen            40.3           18.0              195.0
# 8    Adelie  Torgersen            36.7           19.3              193.0
# 10   Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 676  Gentoo     Biscoe            47.2           13.7              214.0
# 680  Gentoo     Biscoe            46.8           14.3              215.0
# 682  Gentoo     Biscoe            50.4           15.7              222.0
# 684  Gentoo     Biscoe            45.2           14.8              212.0
# 686  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 2         3800.0  Female
# 4         3250.0  Female
# 8         3450.0  Female
# 10        3650.0    Male
# ..           ...     ...
# 676       4925.0  Female
# 680       4850.0  Female
# 682       5750.0    Male
# 684       5200.0  Female
# 686       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## h) ¿Como podemos usar una funcion lambda para renombrar todos los nombres de columnas a mayusculas?

# %%
penguinsClean.rename(columns = lambda x : str.upper(x))
# Out:
#     SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      BODY_MASS_G     SEX
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
# lo volvemos a poner como estaba antes por las dudas
penguinsClean.rename(columns = lambda x : str.lower(x))
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# # Ej 6: Renombrar columnas asignando nueva lista de nombres por listas de comprension

# %% [markdown]
# ## a) ¿Que se espera de este comando?

# %%
[saludo + "!" for saludo in ["hola", "chau"]]

# esperamos que agregue el "!" al final del array ["hola", "chau"]
# Out:
# ['hola!', 'chau!']

# %% [markdown]
# ## b) En "penguins" convertir todos los nombres de variables a mayusculas usando listas de comprension

# %%
penguinsClean.columns= [col.upper() for col in penguinsClean.columns]
penguinsClean
# Out:
#     SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      BODY_MASS_G     SEX
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
# dejemoslo como estaba antes
penguinsClean.columns= [col.lower() for col in penguinsClean.columns]
penguinsClean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# # Ej 7: En "penguins" convertir solo los nombres de variables que empiezan con bill a mayusculas

# %%
penguinsClean.columns= [col.upper() if col.startswith("bill") else col for col in penguinsClean.columns]
penguinsClean
# Out:
#     species     island  BILL_LENGTH_MM  BILL_DEPTH_MM  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
penguinsClean.columns= [col.lower() if col.startswith("BILL") else col for col in penguinsClean.columns]
penguinsClean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# # Ej 8: Usando lamda, agregar una nueva columna a la base de datos llamada peso_bin que contenga
#
# - "chico" si la masa corporal es menos que 4000 gramos
# - "grande" si la masa corporal es mayor que 4000 gramos

# %%
# Agrego lista de comprension tal que cumpla lo pedido, pero ademas, si vale 4000, nos de "medio"
penguinsClean["peso_bin"] = ["chico" if peso < 4000 else "grande" if peso > 4000 else "medio" for peso in penguinsClean["body_mass_g"]]
penguinsClean
# Out:
# /tmp/ipykernel_12906/413807831.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguinsClean["peso_bin"] = ["chico" if peso < 4000 else "grande" if peso > 4000 else "medio" for peso in penguinsClean["body_mass_g"]]
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex peso_bin
# 0         3750.0    Male    chico
# 1         3800.0  Female    chico
# 2         3250.0  Female    chico
# 4         3450.0  Female    chico
# 5         3650.0    Male    chico
# ..           ...     ...      ...
# 338       4925.0  Female   grande
# 340       4850.0  Female   grande
# 341       5750.0    Male   grande
# 342       5200.0  Female   grande
# 343       5400.0    Male   grande
#
# [333 rows x 8 columns]

# %% [markdown]
# # Ej 9: Crear un subconjunto de los datos de "penguins" solo con las observaciones de pinguinos machos con aletas (flipper) de mas de 200mm de largo y quedarse con todas las columnas que terminan con "_mm".

# %%
# Busco 1ro quedarme con el subconj de datos de "penguinsClean" "machos" con "flipper_length_mm" > 200mm
flippers = penguinsClean[(penguinsClean["sex"] == "Male") & (penguinsClean["flipper_length_mm"] > 200)]

# Luego me quedo solo con las columnas que terminen en "_mm"
flippers = flippers[[col for col in penguinsClean.columns if col.endswith("_mm")]]
flippers

# Problema al querer hacer todo en una linea, parece que no se llevan bien las operaciones logicas directas:
# 1. [algo1 == algo2]
# con las operaciones con "for"
# 2. [algo1 for algo2 in lugar if talcosa]
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm
# 91             41.1           18.1              205.0
# 95             40.8           18.9              208.0
# 101            41.0           20.0              203.0
# 123            41.4           18.5              202.0
# 129            44.1           18.0              210.0
# ..              ...            ...                ...
# 333            51.5           16.3              230.0
# 335            55.1           16.0              230.0
# 337            48.8           16.2              222.0
# 341            50.4           15.7              222.0
# 343            49.9           16.1              213.0
#
# [84 rows x 3 columns]

# %% [markdown]
# # Ej 10: Empezando con penguins crear un dataframe con estos requisitos:
#
# - Contenga solo las observaciones de la isla "Dream"
#
# - Contenga solo las variables "species" y todas las que empiecen con "bill"

# %%
# Filtro para que sean todos de la misma isla
penguins3 = penguinsClean[penguinsClean["island"] == "Dream"]

# Busco que las columnas empiecen en "bill" o sea "species"
penguins3 = penguins3[[col for col in penguinsClean.columns if (col.startswith("bill") | col.startswith("species"))]]
penguins3
# Out:
#        species  bill_length_mm  bill_depth_mm
# 30      Adelie            39.5           16.7
# 31      Adelie            37.2           18.1
# 32      Adelie            39.5           17.8
# 33      Adelie            40.9           18.9
# 34      Adelie            36.4           17.0
# ..         ...             ...            ...
# 215  Chinstrap            55.8           19.8
# 216  Chinstrap            43.5           18.1
# 217  Chinstrap            49.6           18.2
# 218  Chinstrap            50.8           19.0
# 219  Chinstrap            50.2           18.7
#
# [123 rows x 3 columns]

# %% [markdown]
# # Ej 11: Empezando con penguins realizar las siguientes operaciones:
#
# - Crear una nueva variable que tenga el peso en kgs
#
# - Convertir la variable "island" a minuscula

# %%
# 1kg = 1000g
penguinsClean["body_mass_kg"] = penguinsClean["body_mass_g"] / 1000

# Como ya estaba en minuscula, la pongo en mayuscula y luego la vuelvo minuscula de nuevo
penguinsClean.columns = [col.upper() if col == "island" else col for col in penguinsClean.columns]
penguinsClean.columns = [col.lower() if col == "ISLAND" else col for col in penguinsClean.columns]
penguinsClean.reset_index(drop = True)
# Out:
# /tmp/ipykernel_12906/2372270659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguinsClean["body_mass_kg"] = penguinsClean["body_mass_g"] / 1000
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 328  Gentoo     Biscoe            47.2           13.7              214.0
# 329  Gentoo     Biscoe            46.8           14.3              215.0
# 330  Gentoo     Biscoe            50.4           15.7              222.0
# 331  Gentoo     Biscoe            45.2           14.8              212.0
# 332  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex peso_bin  body_mass_kg
# 0         3750.0    Male    chico         3.750
# 1         3800.0  Female    chico         3.800
# 2         3250.0  Female    chico         3.250
# 3         3450.0  Female    chico         3.450
# 4         3650.0    Male    chico         3.650
# ..           ...     ...      ...           ...
# 328       4925.0  Female   grande         4.925
# 329       4850.0  Female   grande         4.850
# 330       5750.0    Male   grande         5.750
# 331       5200.0  Female   grande         5.200
# 332       5400.0    Male   grande         5.400
#
# [333 rows x 9 columns]

# %% [markdown]
# # Ej 12: Agregar una columna a "penguins" con la mediana de la masa corporal de los pinguinos de cada especie usando group_by() y agg().

# %%
# Ahora busco calcular la mediana de cada especie
penguins_by_species = penguinsClean.copy()
penguins_by_species["body_mass_median"] = penguins_by_species["body_mass_g"].agg("median",penguins_by_species["species"])

# %% [markdown]
# # ERROR: NO RESUELTO

# %%
penguins_by_species["body_mass_median"] = penguins_by_species.groupby("species")["body_mass_g"].agg("median": penguins_by_species["species"] )
penguins_by_species
# Out:
#   Cell In[48], line 1
#     penguins_by_species["body_mass_median"] = penguins_by_species.groupby("species")["body_mass_g"].agg("median": penguins_by_species["species"] )
#                                                                                                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Ej 13: Empezando con "penguins" escriba una secuencia de operaciones (pipe) que:
#
# - a. Excluya a los pinguinos observados en la isla "Biscoe"
# - b. Solo se quede con las variables que estan entre "species" y "body_mass_g" inclusive
# - c. Renombre la variable species a "especie-pinguino"
# - d. Agrupe los datos por la variable "especie-pinguino"
# - e. Calcule el valor medio de las variables que contienen "length", separando por la especie del pinguino y llamando a las colunas como las originales pero agregando "_mean" al final.

# %%
penguinsClean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex peso_bin  body_mass_kg
# 0         3750.0    Male    chico         3.750
# 1         3800.0  Female    chico         3.800
# 2         3250.0  Female    chico         3.250
# 4         3450.0  Female    chico         3.450
# 5         3650.0    Male    chico         3.650
# ..           ...     ...      ...           ...
# 338       4925.0  Female   grande         4.925
# 340       4850.0  Female   grande         4.850
# 341       5750.0    Male   grande         5.750
# 342       5200.0  Female   grande         5.200
# 343       5400.0    Male   grande         5.400
#
# [333 rows x 9 columns]

# %%
# a) Excluimos a los pinguinos de la isla "Bisoe"
penguins13 = penguinsClean[(penguinsClean["island"] != "Biscoe") & 
            ([col if col != "sex" | "peso_bin" | "body_mass_kg" else 0 for col in penguinsClean.columns]) ]
penguins13
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 3
#       1 # a) Excluimos a los pinguinos de la isla "Bisoe"
#       2 penguins13 = penguinsClean[(penguinsClean["island"] != "Biscoe") &
# ----> 3             ([col if col != "sex" | "peso_bin" | "body_mass_kg" else 0 for col in penguinsClean.columns]) ]
#       4 penguins13
#
# Cell In[84], line 3, in <listcomp>(.0)
#       1 # a) Excluimos a los pinguinos de la isla "Bisoe"
#       2 penguins13 = penguinsClean[(penguinsClean["island"] != "Biscoe") &
# ----> 3             ([col if col != "sex" | "peso_bin" | "body_mass_kg" else 0 for col in penguinsClean.columns]) ]
#       4 penguins13
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
# b) Luego nos quedamos con las variables entre "species" y "body_mass_g" inclusive
columnas_a_quitar = ["sex" , "peso_bin" , "body_mass_kg"]

penguins13 = penguins13[[col for col in penguinsClean.columns if col not in columnas_a_quitar]]
penguins13

# %%
# c) ahora nos pide renombrar la variable "species" a "especie_pinguino"
penguins13 = penguins13.rename(columns = {"species": "especie_pinguino"})
penguins13

# %%
# d) Agrupar los datos por la variable "especie_pinguino"
penguins13.groupby("especie_pinguino")
penguins13
# Out:
#     especie_pinguino     island  bill_length_mm  bill_depth_mm  \
# 0             Adelie  Torgersen            39.1           18.7
# 1             Adelie  Torgersen            39.5           17.4
# 2             Adelie  Torgersen            40.3           18.0
# 4             Adelie  Torgersen            36.7           19.3
# 5             Adelie  Torgersen            39.3           20.6
# ..               ...        ...             ...            ...
# 215        Chinstrap      Dream            55.8           19.8
# 216        Chinstrap      Dream            43.5           18.1
# 217        Chinstrap      Dream            49.6           18.2
# 218        Chinstrap      Dream            50.8           19.0
# 219        Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g
# 0                181.0       3750.0
# 1                186.0       3800.0
# 2                195.0       3250.0
# 4                193.0       3450.0
# 5                190.0       3650.0
# ..                 ...          ...
# 215              207.0       4000.0
# 216              202.0       3400.0
# 217              193.0       3775.0
# 218              210.0       4100.0
# 219              198.0       3775.0
#
# [170 rows x 6 columns]

# %%
# e) Calcular val medio de las variables que contienen "length", 
# separando por especie de pinguino y llamando a las columnas como las originales 
# pero agregando "_mean" al final
